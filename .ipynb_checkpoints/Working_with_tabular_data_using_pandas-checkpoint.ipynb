# %% [markdown]
# ### About this Notebook
# This notebook is tutorial how to deal with relational databases using Pandas.
#
# ### Author
# This notebook was written by Mohammed Alhamid
#
# ### Objective
# Execute SQL queries, perform relaional joins using Panadas library.

# %% [markdown]
# ### Library Used:
#
# Pandas

# %%
import pandas as pd

# %%
# to use the datasets folder in this repristory, we will need to add the directory path
import sys
sys.path.append('../datasets/')

# %%
# We will use TripAdvisor dataset
T1 = pd.read_csv('../datasets/Data_TripAdvisor_v1.csv', header=0)
T1
# Out:
#       ID_USER USER_STATE USER_TIMEZONE  ID_HOTEL   HOTEL_CITY HOTEL_STATE  \
# 0          45         GA       Eastern    105170      Memphis          TN
# 1          45         GA       Eastern    223229   SanAntonio          TX
# 2          45         GA       Eastern    258688  Albuquerque          NM
# 3          45         GA       Eastern     98827       ELPaso          TX
# 4          45         GA       Eastern     99518   SanAntonio          TX
# ...       ...        ...           ...       ...          ...         ...
# 4664    65440         MI       Eastern     95715  Minneapolis          MN
# 4665    65457         AZ      Mountain   1027019    FortWorth          TX
# 4666    65457         AZ      Mountain    224458    Milwaukee          WI
# 4667    65457         AZ      Mountain    223749     Columbus          OH
# 4668    65457         AZ      Mountain     92744  Albuquerque          NM
#
#      HOTEL_TIMEZONE  Trip Type  Rating
# 0           Central          3       5
# 1           Central          3       5
# 2          Mountain          3       5
# 3           Central          3       5
# 4           Central          3       3
# ...             ...        ...     ...
# 4664        Central          4       5
# 4665        Central          3       3
# 4666        Central          3       3
# 4667        Eastern          3       2
# 4668       Mountain          4       3
#
# [4669 rows x 9 columns]

# %%
# The seconds table contains simply the trip types 
T2 = pd.read_csv('../datasets/Data_TripAdvisor_v1_trip_type.csv', header=None)
T2.columns = ['type_idx', 'type_name']
T2
# Out:
#    type_idx    type_name
# 0         1       Family
# 1         2      Couples
# 2         3     Business
# 3         4  Solo travel
# 4         5      Friends

# %%
T1.columns
# Out:
# Index(['ID_USER', 'USER_STATE', 'USER_TIMEZONE', 'ID_HOTEL', 'HOTEL_CITY',
#        'HOTEL_STATE', 'HOTEL_TIMEZONE', 'Trip Type', 'Rating'],
#       dtype='object')

# %% [markdown]
# ## SQL Queries

# %% [markdown]
# #### <font color = "blue"> Example 1 -- Fetching n rows</font>

# %%
# We want to fetch the first five rows from T1

# %%
'''
select * from T1 limit 5
'''
# Out:
# '\nselect * from T1 limit 5\n'

# %%
T1.head(5)
# Out:
#    ID_USER USER_STATE USER_TIMEZONE  ID_HOTEL   HOTEL_CITY HOTEL_STATE  \
# 0       45         GA       Eastern    105170      Memphis          TN
# 1       45         GA       Eastern    223229   SanAntonio          TX
# 2       45         GA       Eastern    258688  Albuquerque          NM
# 3       45         GA       Eastern     98827       ELPaso          TX
# 4       45         GA       Eastern     99518   SanAntonio          TX
#
#   HOTEL_TIMEZONE  Trip Type  Rating
# 0        Central          3       5
# 1        Central          3       5
# 2       Mountain          3       5
# 3        Central          3       5
# 4        Central          3       3

# %% [markdown]
# #### <font color = "blue"> Example 2 - Column Predicate</font>

# %%
# Let's find the details of a givn hotel id 223749

# %%
# We can select the desired rows using Pandas.Query or filter out the rows on the dataframe directly

# %%
# The equivalent SQL command 
'''
select *  

from T1

where ID_HOTEL=223749

;
'''
# Out:
# '\nselect *  \n\nfrom T1\n\nwhere ID_HOTEL=223749\n\n;\n'

# %%
T1.query('ID_HOTEL==223749')
# Out:
#       ID_USER USER_STATE USER_TIMEZONE  ID_HOTEL HOTEL_CITY HOTEL_STATE  \
# 2417    33899         IL       Central    223749   Columbus          OH
# 4222    59232         VA       Eastern    223749   Columbus          OH
# 4667    65457         AZ      Mountain    223749   Columbus          OH
#
#      HOTEL_TIMEZONE  Trip Type  Rating
# 2417        Eastern          3       2
# 4222        Eastern          3       2
# 4667        Eastern          3       2

# %%
# The above command can be rewritten as the following: 
T1[T1['ID_HOTEL'] == 223749]
# Out:
#       ID_USER USER_STATE USER_TIMEZONE  ID_HOTEL HOTEL_CITY HOTEL_STATE  \
# 2417    33899         IL       Central    223749   Columbus          OH
# 4222    59232         VA       Eastern    223749   Columbus          OH
# 4667    65457         AZ      Mountain    223749   Columbus          OH
#
#      HOTEL_TIMEZONE  Trip Type  Rating
# 2417        Eastern          3       2
# 4222        Eastern          3       2
# 4667        Eastern          3       2

# %% [markdown]
# #### <font color = "blue"> Example 3 - Distinct Values</font>

# %%
# Getting the distinct values in a USER_TIMEZONE column

# %%
# The equivalent SQL command 
'''
select distinct HOTEL_TIMEZONE 

from T1

;
'''
# Out:
# '\nselect distinct HOTEL_TIMEZONE \n\nfrom T1\n\n;\n'

# %%
T1['USER_TIMEZONE'].unique()
# Out:
# array(['Eastern', 'Central', 'Pacific', 'Mountain', 'HI', 'AK'],
#       dtype=object)

# %% [markdown]
# #### <font color = "blue"> Example 4 - 'In' Clause</font>

# %%
# Retriving all rows that have the values 'OH' or 'TX' as their HOTEL_STATE

# %%
# The equivalent SQL command 
'''
select *  

from T1

where HOTEL_STATE in ('OH', 'TX')

;
'''
# Out:
# "\nselect *  \n\nfrom T1\n\nwhere HOTEL_STATE in ('OH', 'TX')\n\n;\n"

# %%
T1[T1['HOTEL_STATE'].isin(['OH', 'TX'])]
# Out:
#       ID_USER USER_STATE USER_TIMEZONE  ID_HOTEL  HOTEL_CITY HOTEL_STATE  \
# 1          45         GA       Eastern    223229  SanAntonio          TX
# 3          45         GA       Eastern     98827      ELPaso          TX
# 4          45         GA       Eastern     99518  SanAntonio          TX
# 5          64         TX       Central    224427   Cleveland          OH
# 6          64         TX       Central   1751886      Austin          TX
# ...       ...        ...           ...       ...         ...         ...
# 4652    65384         TX       Central   1688532  SanAntonio          TX
# 4653    65406         FL       Eastern    109093   FortWorth          TX
# 4656    65406         FL       Eastern    543350   FortWorth          TX
# 4665    65457         AZ      Mountain   1027019   FortWorth          TX
# 4667    65457         AZ      Mountain    223749    Columbus          OH
#
#      HOTEL_TIMEZONE  Trip Type  Rating
# 1           Central          3       5
# 3           Central          3       5
# 4           Central          3       3
# 5           Eastern          1       4
# 6           Central          3       4
# ...             ...        ...     ...
# 4652        Central          2       2
# 4653        Central          3       3
# 4656        Central          4       5
# 4665        Central          3       3
# 4667        Eastern          3       2
#
# [1391 rows x 9 columns]

# %%
# Another way to execute the command: 
T1.query('HOTEL_STATE in [\'OH\', \'TX\']')
# Out:
#       ID_USER USER_STATE USER_TIMEZONE  ID_HOTEL  HOTEL_CITY HOTEL_STATE  \
# 1          45         GA       Eastern    223229  SanAntonio          TX
# 3          45         GA       Eastern     98827      ELPaso          TX
# 4          45         GA       Eastern     99518  SanAntonio          TX
# 5          64         TX       Central    224427   Cleveland          OH
# 6          64         TX       Central   1751886      Austin          TX
# ...       ...        ...           ...       ...         ...         ...
# 4652    65384         TX       Central   1688532  SanAntonio          TX
# 4653    65406         FL       Eastern    109093   FortWorth          TX
# 4656    65406         FL       Eastern    543350   FortWorth          TX
# 4665    65457         AZ      Mountain   1027019   FortWorth          TX
# 4667    65457         AZ      Mountain    223749    Columbus          OH
#
#      HOTEL_TIMEZONE  Trip Type  Rating
# 1           Central          3       5
# 3           Central          3       5
# 4           Central          3       3
# 5           Eastern          1       4
# 6           Central          3       4
# ...             ...        ...     ...
# 4652        Central          2       2
# 4653        Central          3       3
# 4656        Central          4       5
# 4665        Central          3       3
# 4667        Eastern          3       2
#
# [1391 rows x 9 columns]

# %% [markdown]
# We can see the exact same rows are retriving using both approaches

# %% [markdown]
# #### <font color = "blue"> Example 5 - Selecting Columns </font>

# %%
# The equivalent SQL command 
'''
select ID_HOTEL, TripType, Rating 

from T1

;
'''

# %%
T1[['ID_HOTEL', 'Trip Type', 'Rating']]
# Out:
#       ID_HOTEL  Trip Type  Rating
# 0       105170          3       5
# 1       223229          3       5
# 2       258688          3       5
# 3        98827          3       5
# 4        99518          3       3
# ...        ...        ...     ...
# 4664     95715          4       5
# 4665   1027019          3       3
# 4666    224458          3       3
# 4667    223749          3       2
# 4668     92744          4       3
#
# [4669 rows x 3 columns]

# %% [markdown]
# ## Table Merge

# %% [markdown]
# Let's do an inner join between T1 and T2 that's equivalent to the following SQL command:

# %%
# The equivalent SQL command 
'''
select
    *
from
    t1
    inner join
    t2
    on t1.trip_type = t2.type_idx
;
'''
# Out:
# '\nselect\n    *\nfrom\n    t1\n    inner join\n    t2\n    on t1.trip_type = t2.type_idx\n;\n'

# %%
T1.merge(T2, left_on='Trip Type', right_on='type_idx', how='inner')
# Out:
#       ID_USER USER_STATE USER_TIMEZONE  ID_HOTEL   HOTEL_CITY HOTEL_STATE  \
# 0          45         GA       Eastern    105170      Memphis          TN
# 1          45         GA       Eastern    223229   SanAntonio          TX
# 2          45         GA       Eastern    258688  Albuquerque          NM
# 3          45         GA       Eastern     98827       ELPaso          TX
# 4          45         GA       Eastern     99518   SanAntonio          TX
# ...       ...        ...           ...       ...          ...         ...
# 4664    64370         KS       Central     95840        Tulsa          OK
# 4665    64487         OH       Eastern    240681      Phoenix          AZ
# 4666    64487         OH       Eastern     74587      Phoenix          AZ
# 4667    64851         TX       Central    109748      Houston          TX
# 4668    64851         TX       Central    141902      Houston          TX
#
#      HOTEL_TIMEZONE  Trip Type  Rating  type_idx type_name
# 0           Central          3       5         3  Business
# 1           Central          3       5         3  Business
# 2          Mountain          3       5         3  Business
# 3           Central          3       5         3  Business
# 4           Central          3       3         3  Business
# ...             ...        ...     ...       ...       ...
# 4664        Central          5       4         5   Friends
# 4665       Mountain          5       4         5   Friends
# 4666       Mountain          5       4         5   Friends
# 4667        Central          5       3         5   Friends
# 4668        Central          5       2         5   Friends
#
# [4669 rows x 11 columns]

# %%
# Sometimes we need to get some indication whether the row from T2 are showing up in T1 for other types of joins like 
#left or right joins. 
# We need to use 'Indicator' parameter 
T1.merge(T2, left_on='Trip Type', right_on='type_idx', how='inner', indicator=True)
# Out:
#       ID_USER USER_STATE USER_TIMEZONE  ID_HOTEL   HOTEL_CITY HOTEL_STATE  \
# 0          45         GA       Eastern    105170      Memphis          TN
# 1          45         GA       Eastern    223229   SanAntonio          TX
# 2          45         GA       Eastern    258688  Albuquerque          NM
# 3          45         GA       Eastern     98827       ELPaso          TX
# 4          45         GA       Eastern     99518   SanAntonio          TX
# ...       ...        ...           ...       ...          ...         ...
# 4664    64370         KS       Central     95840        Tulsa          OK
# 4665    64487         OH       Eastern    240681      Phoenix          AZ
# 4666    64487         OH       Eastern     74587      Phoenix          AZ
# 4667    64851         TX       Central    109748      Houston          TX
# 4668    64851         TX       Central    141902      Houston          TX
#
#      HOTEL_TIMEZONE  Trip Type  Rating  type_idx type_name _merge
# 0           Central          3       5         3  Business   both
# 1           Central          3       5         3  Business   both
# 2          Mountain          3       5         3  Business   both
# 3           Central          3       5         3  Business   both
# 4           Central          3       3         3  Business   both
# ...             ...        ...     ...       ...       ...    ...
# 4664        Central          5       4         5   Friends   both
# 4665       Mountain          5       4         5   Friends   both
# 4666       Mountain          5       4         5   Friends   both
# 4667        Central          5       3         5   Friends   both
# 4668        Central          5       2         5   Friends   both
#
# [4669 rows x 12 columns]

# %% [markdown]
# ## Multi-Column Precicates

# %% [markdown]
# #### <font color = "blue"> Example 6 - Multi-column predicates </font>

# %%
# We want fetch all rows that satisfy two conditions: Rating =5 and HOTEL_STATE in [OH,TX]

# %%
# The equivalent SQL command 
'''
select 
    *
from t1 

where rating = 5 and hotel_state in ('OH', 'TX')
;
'''
# Out:
# "\nselect \n    *\nfrom t1 \n\nwhere rating = 5 and hotel_state in ('OH', 'TX')\n;\n"

# %%
T1[(T1['Rating'] ==5 ) & (T1['HOTEL_STATE'].isin(['OH', 'TX']))]
# Out:
#       ID_USER USER_STATE USER_TIMEZONE  ID_HOTEL  HOTEL_CITY HOTEL_STATE  \
# 1          45         GA       Eastern    223229  SanAntonio          TX
# 3          45         GA       Eastern     98827      ELPaso          TX
# 24        215         TX       Central    240439     Houston          TX
# 28        221         CT       Eastern   1199983   Arlington          TX
# 29        221         CT       Eastern   1199983   Arlington          TX
# ...       ...        ...           ...       ...         ...         ...
# 4556    64067         TX       Central    223620      Austin          TX
# 4557    64067         TX       Central    225120   FortWorth          TX
# 4621    64799         CA       Pacific     99470  SanAntonio          TX
# 4651    65384         TX       Central    223620      Austin          TX
# 4656    65406         FL       Eastern    543350   FortWorth          TX
#
#      HOTEL_TIMEZONE  Trip Type  Rating
# 1           Central          3       5
# 3           Central          3       5
# 24          Central          3       5
# 28          Central          3       5
# 29          Central          3       5
# ...             ...        ...     ...
# 4556        Central          2       5
# 4557        Central          2       5
# 4621        Central          4       5
# 4651        Central          1       5
# 4656        Central          4       5
#
# [315 rows x 9 columns]

# %%
# Another way of executing the command
T1.query('Rating == 5 & HOTEL_STATE in [\'OH\', \'TX\']')
# Out:
#       ID_USER USER_STATE USER_TIMEZONE  ID_HOTEL  HOTEL_CITY HOTEL_STATE  \
# 1          45         GA       Eastern    223229  SanAntonio          TX
# 3          45         GA       Eastern     98827      ELPaso          TX
# 24        215         TX       Central    240439     Houston          TX
# 28        221         CT       Eastern   1199983   Arlington          TX
# 29        221         CT       Eastern   1199983   Arlington          TX
# ...       ...        ...           ...       ...         ...         ...
# 4556    64067         TX       Central    223620      Austin          TX
# 4557    64067         TX       Central    225120   FortWorth          TX
# 4621    64799         CA       Pacific     99470  SanAntonio          TX
# 4651    65384         TX       Central    223620      Austin          TX
# 4656    65406         FL       Eastern    543350   FortWorth          TX
#
#      HOTEL_TIMEZONE  Trip Type  Rating
# 1           Central          3       5
# 3           Central          3       5
# 24          Central          3       5
# 28          Central          3       5
# 29          Central          3       5
# ...             ...        ...     ...
# 4556        Central          2       5
# 4557        Central          2       5
# 4621        Central          4       5
# 4651        Central          1       5
# 4656        Central          4       5
#
# [315 rows x 9 columns]
